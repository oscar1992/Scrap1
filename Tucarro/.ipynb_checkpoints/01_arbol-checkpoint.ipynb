# %%
import pandas as pd
import numpy as np
import os
import datetime
import re

from bs4 import BeautifulSoup
import requests

# %%
def multiplos_49(num):
    multiples = []
    for i in range(1,num):
        if i % 49 == 0:
            multiples.append(i)
    return multiples

def arreglar_publicacion(entrada):
    numero_actual = int(re.findall(r'\d+', entrada)[0])
    respuesta = pd.Timestamp(datetime.date.today())
    if ('día' in entrada) or ('dia' in entrada):
        respuesta = pd.Timestamp(datetime.date.today()) - pd.Timedelta(days = numero_actual)
    elif 'mes' in entrada:
        respuesta = pd.Timestamp(datetime.date.today()) - pd.Timedelta(days = numero_actual*30)
    else:
        respuesta = pd.Timestamp(datetime.date.today()) - pd.Timedelta(days = numero_actual*365)
        
    return pd.Timestamp(respuesta.date())

def calcular_numero_carros(entrada):
    response = requests.get(entrada)
    soup = BeautifulSoup(response.content, 'html.parser')
    search_span = soup.find('span', class_=lambda x: x and 'ui-search-search' in x)
    print(search_span.text)
    return int(search_span.text.replace(' resultados', '').replace('.', ''))






def informacion_carros_actuales (entrada):
    ## Conseguir URL's de carros en pagina actual
    response = requests.get(entrada)
    soup = BeautifulSoup(response.content, 'html.parser')
    links_carros = soup.find_all('a', href =lambda x: x and 'articulo.tucarro.com' in x)
    hrefs_carros = [link.get("href") for link in links_carros]
    hrefs_carros = list(set(hrefs_carros))
    ## Iterar sobre cada carro para obtener su informacion
    for carro in hrefs_carros:
        conseguir_informacion_carro(carro)

# %%
url = 'https://carros.tucarro.com.co/_FiltersAvailableSidebar?filter=MODEL'

response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
links = soup.find_all('a')
modelos = ['/'.join(link.get("href").split('/')[:4])+'/_NoIndex_True' for link in links if ('tech-and-cookies' not in str(link.get("href")))]

# %%
contador_modelos = 0
total_modelos = len(modelos)
for modelo in modelos:
    ## Imprimir informacion del modelo
    contador_modelos +=1
    print(f'Este es el modelo {contador_modelos} de {total_modelos}')
    print('--')
    print(modelo)
    print('--')
    ## Obtener numero de carros de este modelo
    numero_carros = calcular_numero_carros(modelo)
    ## Obtener informacion de carros pagina actual
    informacion_carros_actuales(modelo)
    ## Iterar sobre_paginas del mismo modelo
    for numero_pagina in multiplos_49(numero_carros):
        ## Obtener URL de la pagina actual
        modificacion = f'_Desde_{numero_pagina}_NoIndex_True'
        url_actual = modelo.replace('_NoIndex_True', modificacion)
        ## Extraer informacion carros de esta pagina
        informacion_carros_actuales(url_actual)
    print('--------------------------------')

# %%
def conseguir_informacion_carro (entrada):
    response = requests.get(entrada)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    ## Short_Description
    short_description = soup.find('div', class_=lambda x: x and 'short-description' in x)
    
    year = int(short_description.find('span').text.split('|')[0])
    
    kilometros = int(short_description.find('span').text.split('|')[1].split('km')[0].replace('.', ''))
    
    publicacion = short_description.find('span').text.split('Publicado')[1]
    fecha_publicacion = arreglar_publicacion(publicacion)
    
    titulo = short_description.find('h1').text
    
    precio = int(short_description.find('meta').get('content'))
    
    ## Seller_Profile
    seller_profile = soup.find('div', class_=lambda x: x and 'seller-profile' in x)
    
    ## Specs_Table
    specs_table = soup.find('div', class_=lambda x: x and 'specs__table' in x )

# %%
a = 'https://articulo.tucarro.com.co/MCO-1268666883-chevrolet-tracker-ltz-mod-2019-4x4-aut-_JM#position=1&search_layout=grid&type=item&tracking_id=14a10e93-d05d-4f3b-8911-a79a1eee4b01'
response = requests.get(a)
soup = BeautifulSoup(response.content, 'html.parser')
sou = soup.find('div', class_=lambda x: x and 'pdp-container--pdp' in x)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="es-CO">
#  <head>
#   <link href="https://www.google-analytics.com" rel="preconnect"/>
#   <link href="https://www.google.com" rel="preconnect"/>
#   <link href="https://data.mercadolibre.com" rel="preconnect"/>
#   <link href="https://http2.mlstatic.com" rel="preconnect"/>
#   <link href="https://stats.g.doubleclick.net" rel="preconnect"/>
#   <link href="https://analytics.tucarro.com.co" rel="preconnect"/>
#   <link href="https://analytics.tucarro.com" rel="preconnect"/>
#   <link href="https://analytics.mercadolibre.com" rel="preconnect"/>
#   <link href="https://www.google.com.co" rel="preconnect"/>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"NRBR-6b78f6637d1702173e8","applicationID":"1588198355","agentToken":null,"applicationTime":158.591866,"transactionName":"YlZQYEVZC0QEV0BZV1scd0xHSgBEFl5HH39wZx0bDUgXWAFBV0RxURsab1YVH3ZIbmlLC0geaQQaATgcTBweGRE=","queueTime":0,"ttGuid":"bb09e8798e047d22"}; (window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:true},ajax:{deny_list:["bam.nr-data.net"]},distributed_tracing:{enabled:true}};(window.NREUM||(NREUM={})).loader_config={agentID:"1834853436",accountID:"989586",trustKey:"1709707",xpid:"XQ4OVF5VGwIFXFlTDgkEU1E=",licenseKey:"NRBR-6b78f6637d1702173e8",applicationID:"1588198355"};;(()=>{var e,t,r={9071:(e,t,r)=>{"use strict";r.d(t,{I:()=>n});var n=0,i=navigator.userAgent.match(/Firefox[\/\s](\d+\.\d+)/);i&&(n=+i[1])},6562:(e,t,r)=>{"use strict";r.d(t,{P_:()=>p,Mt:()=>v,C5:()=>f,DL:()=>y,OP:()=>R,lF:()=>L,Yu:()=>E,Dg:()=>g,CX:()=>d,GE:()=>w,sU:()=>k});var n={};r.r(n),r.d(n,{agent:()=>T,match:()=>S,version:()=>A});var i=r(6797),o=r(909),a=r(8610);class s{constructor(e,t){try{if(!e||"object"!=typeof e)return(0,a.Z)("New setting a Configurable requires an object as input");if(!t||"object"!=typeof t)return(0,a.Z)("Setting a Configurable requires a model to set its initial properties");Object.assign(this,t),Object.entries(e).forEach((e=>{let[t,r]=e;const n=(0,o.q)(t);n.length&&r&&"object"==typeof r&&n.forEach((e=>{e in r&&((0,a.Z)('"'.concat(e,'" is a protected attribute and can not be changed in feature ').concat(t,".  It will have no effect.")),delete r[e])})),this[t]=r}))}catch(e){(0,a.Z)("An error occured while setting a Configurable",e)}}}const c={beacon:i.ce.beacon,errorBeacon:i.ce.errorBeacon,licenseKey:void 0,applicationID:void 0,sa:void 0,queueTime:void 0,applicationTime:void 0,ttGuid:void 0,user:void 0,account:void 0,product:void 0,extra:void 0,jsAttributes:{},userAttributes:void 0,atts:void 0,transactionName:void 0,tNamePlain:void 0},u={};function f(e){if(!e)throw new Error("All info objects require an agent identifier!");if(!u[e])throw new Error("Info for ".concat(e," was never set"));return u[e]}function d(e,t){if(!e)throw new Error("All info objects require an agent identifier!");u[e]=new s(t,c),(0,i.Qy)(e,u[e],"info")}const l={allow_bfcache:!0,privacy:{cookies_enabled:!0},ajax:{deny_list:void 0,enabled:!0,harvestTimeSeconds:10},distributed_tracing:{enabled:void 0,exclude_newrelic_header:void 0,cors_use_newrelic_header:void 0,cors_use_tracecontext_headers:void 0,allowed_origins:void 0},ssl:void 0,obfuscate:void 0,jserrors:{enabled:!0,harvestTimeSeconds:10},metrics:{enabled:!0},page_action:{enabled:!0,harvestTimeSeconds:30},page_view_event:{enabled:!0},page_view_timing:{enabled:!0,harvestTimeSeconds:30,long_task:!1},session_trace:{enabled:!0,harvestTimeSeconds:10},spa:{enabled:!0,harvestTimeSeconds:10}},h={};function p(e){if(!e)throw new Error("All configuration objects require an agent identifier!");if(!h[e])throw new Error("Configuration for ".concat(e," was never set"));return h[e]}function g(e,t){if(!e)throw new Error("All configuration objects require an agent identifier!");h[e]=new s(t,l),(0,i.Qy)(e,h[e],"config")}function v(e,t){if(!e)throw new Error("All configuration objects require an agent identifier!");var r=p(e);if(r){for(var n=t.split("."),i=0;i<n.length-1;i++)if("object"!=typeof(r=r[n[i]]))return;r=r[n[n.length-1]]}return r}const m={accountID:void 0,trustKey:void 0,agentID:void 0,licenseKey:void 0,applicationID:void 0,xpid:void 0},b={};function y(e){if(!e)throw new Error("All loader-config objects require an agent identifier!");if(!b[e])throw new Error("LoaderConfig for ".concat(e," was never set"));return b[e]}function w(e,t){if(!e)throw new Error("All loader-config objects require an agent identifier!");b[e]=new s(t,m),(0,i.Qy)(e,b[e],"loader_config")}const E=(0,i.mF)().o;var T=null,A=null;if(navigator.userAgent){var x=navigator.userAgent,_=x.match(/Version\/(\S+)\s+Safari/); ...
#   </script>
#   <script id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">
#    [9351,6345,2649,2510,453,9200,2030]
#   </script>
#   <script id="__LOADABLE_REQUIRED_CHUNKS___ext" type="application/json">
#    {"namedChunks":["action"]}
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=5.0" name="viewport"/>
#   <meta content="True" name="HandheldFriendly"/>
#   <meta content="on" http-equiv="cleartype"/>
#   <meta content="samesite=true" name="browser-support"/>
#   <meta content="bDQwZdyy-Ur_DlBZUYYz_Uajy5smm9LgNibs" name="csrf-token"/>
#   <link as="font" crossorigin="anonymous" data-head-react="true" href="https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-light.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" data-head-react="true" href="https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-regular.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" data-head-react="true" href="https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-semibold.woff2" rel="preload" type="font/woff2"/>
#   <style data-head-react="true">
#    @font-face{font-family:'Proxima Nova';font-weight:300;font-display:swap;font-style:normal;src:url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-light.woff2) format("woff2"),url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-light.woff) format("woff"),url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-light.ttf) format("truetype")}@font-face{font-family:'Proxima Nova';font-weight:400;font-display:swap;font-style:normal;src:url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-regular.woff2) format("woff2"),url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-regular.woff) format("woff"),url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-regular.ttf) format("truetype")}@font-face{font-family:'Proxima Nova';font-weight:600;font-display:swap;font-style:normal;src:url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-semibold.woff2) format("woff2"),url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-semibold.woff) format("woff"),url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-semibold.ttf) format("truetype")}
#   </style>
#   <link data-head-react="true" href="https://http2.mlstatic.com/frontend-assets/vis-web-navigation/ui-navigation/5.19.7/tucarro/favicon.svg" rel="icon"/>
#   <link data-head-react="true" href="https://http2.mlstatic.com/frontend-assets/vis-web-navigation/ui-navigation/5.19.7/tucarro/180x180.png" rel="apple-touch-icon"/>
#   <meta content="bDQwZdyy-Ur_DlBZUYYz_Uajy5smm9LgNibs" data-head-react="true" name="csrf-token"/>
#   <script type="application/ld+json">
#    {"name":"Chevrolet Tracker Ltz Mod 2019 4x4 Aut","image":"https:\u002F\u002Fhttp2.mlstatic.com\u002FD_NQ_NP_973198-MCO54244390411_032023-O.webp","offers":{"price":85900000,"availability":"http:\u002F\u002Fschema.org\u002FInStock","url":"https:\u002F\u002Fcarro.mercadolibre.com.co\u002FMCO-1268666883-chevrolet-tracker-ltz-mod-2019-4x4-aut-_JM","@type":"Offer","priceCurrency":"COP","priceValidUntil":"2023-03-31"},"brand":"Chevrolet","sku":"MCO1268666883","color":"Negro","@context":"http:\u002F\u002Fschema.org","@type":"Vehicle","itemCondition":"https:\u002F\u002Fschema.org\u002FUsedCondition","productID":"MCO1268666883","bodyType":"Camioneta","fuelType":"Gasolina","numberOfDoors":"5","vehicleEngine":"1.8","vehicleTransmission":"Automática"}
#   </script>
#   <script type="application/ld+json">
#    {"@context":"http:\u002F\u002Fschema.org","@type":"BreadcrumbList","itemListElement":[{"position":1,"item":{"name":"Carros, Motos y Otros","@id":"https:\u002F\u002Fvehiculos.tucarro.com.co\u002F"},"@type":"ListItem"},{"position":2,"item":{"name":"Carros y Camionetas","@id":"https:\u002F\u002Fcarros.tucarro.com.co\u002F"},"@type":"ListItem"},{"position":3,"item":{"name":"Chevrolet","@id":"https:\u002F\u002Fcarros.tucarro.com.co\u002Fchevrolet\u002F"},"@type":"ListItem"},{"position":4,"item":{"name":"Tracker","@id":"https:\u002F\u002Fcarros.tucarro.com.co\u002Fchevrolet\u002Ftracker\u002F"},"@type":"ListItem"}]}
#   </script>
#   <script type="application/ld+json">
#    {"about":"Características principales","@context":"http:\u002F\u002Fschema.org","@type":"Table"}
#   </script>
#   <meta content="Chevrolet Tracker 1.8 Ltz" data-head-react="true" name="description"/>
#   <meta content="product" data-head-react="true" name="twitter:card"/>
#   <meta content="TuCarro" data-head-react="true" name="twitter:site"/>
#   <meta content="Chevrolet Tracker 1.8 Ltz" data-head-react="true" name="twitter:title"/>
#   <meta content="!CONTINAUTOS HARÁ REALIDAD DE TENER EL USADO QUE DESEAS!Recibimos tú vehículo como parte de pago y manejamos excelentes opciones de financiación.Estamos ubicados en:Continautos Avenida 68 # 20 - 71, BogotáContinautos Autopista Norte # 127 d - 60, Bogotá" data-head-react="true" name="twitter:description"/>
#   <meta content="https://http2.mlstatic.com/D_NQ_NP_973198-MCO54244390411_032023-O.jpg" data-head-react="true" name="twitter:image"/>
#   <meta content="mercadolibre.com.co" data-head-react="true" name="twitter:domain"/>
#   <meta content="Mercado Libre" data-head-react="true" name="twitter:app:name:iphone"/>
#   <meta content="463624852" data-head-react="true" name="twitter:app:id:iphone"/>
#   <meta content="meli://item?id=MCO1268666883" data-head-react="true" name="twitter:app:url:iphone"/>
#   <meta content="Mercado Libre" data-head-react="true" name="twitter:app:name:ipad"/>
#   <meta content="463624852" data-head-react="true" name="twitter:app:id:ipad"/>
#   <meta content="meli://item?id=MCO1268666883" data-head-react="true" name="twitter:app:url:ipad"/>
#   <meta content="Mercado Libre" data-head-react="true" name="twitter:app:name:googleplay"/>
#   <meta content="com.mercadolibre" data-head-react="true" name="twitter:app:id:googleplay"/>
#   <meta content="meli://item?id=MCO1268666883" data-head-react="true" name="twitter:app:url:googleplay"/>
#   <meta content="!CONTINAUTOS HARÁ REALIDAD DE TENER EL USADO QUE DESEAS!Recibimos tú vehículo como parte de pago y manejamos excelentes opciones de financiación.Estamos ubicados en:Continautos Avenida 68 # 20 - 71, BogotáContinautos Autopista Norte # 127 d - 60, Bogotá" data-head-react="true" property="og:description"/>
#   <meta content="https://http2.mlstatic.com/D_NQ_NP_973198-MCO54244390411_032023-O.jpg" data-head-react="true" property="og:image"/>
#   <meta content="Chevrolet Tracker 1.8 Ltz - $ 85.900.000" data-head-react="true" property="og:title"/>
#   <meta content="meli-co:product" data-head-react="true" property="og:type"/>
#   <meta content="https://articulo.tucarro.com.co/MCO-1268666883-chevrolet-tracker-ltz-mod-2019-4x4-aut-_JM" data-head-react="true" property="og:url"/>
#   <meta content="130118353782124" data-head-react="true" property="fb:app_id"/>
#   <meta content="meli://item?id=MCO1268666883" data-head-react="true" name="al:android:url" property="al:android:url"/>
#   <meta content="Mercado Libre" data-head-react="true" name="al:android:app_name" property="al:android:app_name"/>
#   <meta content="com.mercadolibre" data-head-react="true" name="al:android:package" property="al:android:package"/>
#   <meta content="meli://item?id=MCO1268666883" data-head-react="true" name="al:iphone:url" property="al:ios:url"/>
#   <meta content="Mercado Libre" data-head-react="true" name="al:iphone:app_name" property="al:ios:app_name"/>
#   <meta content="463624852" data-head-react="true" name="al:iphone:app_store_id" property="al:ios:app_store_id"/>
#   <title>
#    Chevrolet Tracker 1.8 Ltz | TuCarro
#   </title>
#   <link data-head-react="true" href="https://articulo.tucarro.com.co/MCO-1268666883-chevrolet-tracker-ltz-mod-2019-4x4-aut-_JM" rel="canonical"/>
#   <link data-head-react="true" href="ios-app://463624852/meli/item?id=MCO1268666883" rel="alternate"/>
#   <link data-head-react="true" href="android-app://com.mercadolibre/meli/item?id=MCO1268666883" rel="alternate"/>
#   <link as="image" data-head-react="true" fetchpriority="high" href="https://http2.mlstatic.com/D_NQ_NP_973198-MCO54244390411_032023-O.jpg" rel="preload"/>
#   <link data-head-react="true" href="https://www.youtube.com" rel="preconnect"/>
#   <link data-head-react="true" href="https://securepubads.g.doubleclick.net" rel="preconnect"/>
#   <link data-head-react="true" href="https://www.googletagservices.com" rel="preconnect"/>
#   <style>
#    .nav-new-cookie-disclaimer{background:#333;border-top-left-radius:6px;border-top-right-radius:6px;box-shadow:0 6px 16px 0 rgba(0,0,0,.1);padding:16px;position:fixed;bottom:0;left:0;right:0;z-index:2147483647;border:1px solid rgba(0,0,0,.12);font-family:Proxima Nova,-apple-system,Helvetica Neue,Helvetica,Roboto,Arial,sans-serif}.nav-new-cookie-disclaimer__text{color:#fff;font-size:16px;margin:0 0 24px;font-weight:400;-webkit-font-smoothing:antialiased;line-height:1.45}.nav-new-cookie-disclaimer__text a{color:#fff!important;text-decoration:underline!important;white-space:nowrap}.nav-new-cookie-disclaimer__text a:hover,.nav-new-cookie-disclaimer__text a:visited{color:#bfbfbf!important;text-decoration:underline!important}.nav-new-cookie-disclaimer__button{font-size:14px;font-weight:600;font-family:inherit;line-height:1.14;overflow:visible;text-transform:none;background-color:#3483fa;color:#fff;margin:0;padding:7px 12px;width:100%;border:1px solid #3483fa;border-radius:6px;cursor:pointer;-webkit-appearance:button}.nav-new-cookie-disclaimer__button:focus{outline:0;box-shadow:0 0 0 .1875em rgba(41,104,200,.3);-webkit-transition:box-shadow .25s ease-in;transition:box-shadow .25s ease-in}.nav-new-cookie-disclaimer__button:hover{-webkit-transition:background-color .2s ease-in;transition:background-color .2s ease-in}.nav-new-cookie-disclaimer__button:active,.nav-new-cookie-disclaimer__button:hover{border-color:transparent;background-color:#2968c8;color:#fff}@media(min-width:768px){.nav-new-cookie-disclaimer{display:-webkit-flex;display:flex;-webkit-justify-content:center;justify-content:center;-webkit-align-items:center;align-items:center}.nav-new-cookie-disclaimer__text{margin:0 16px 0 0}.nav-new-cookie-disclaimer__button{width:auto}}.cookies-banner-top-content{position:absolute;bottom:100%}.cookies-banner-top-content:not(.cookies-banner-top-content:empty){padding-bottom:16px}
#   </style>
#   <style>
#    @charset "utf-8";
# /*
#  * Navigation
#  * @platform "tucarro"
#  * @version 5.19.7
#  * @author MercadoLibre.com
#  */
# @font-face{font-family:"navigation";src:url("https://http2.mlstatic.com/frontend-assets/vis-web-navigation/ui-navigation/5.19.7/tucarro/navigation.eot");src:url("https://http2.mlstatic.com/frontend-assets/vis-web-navigation/ui-navigation/5.19.7/tucarro/navigation.eot#iefix") format("embedded-opentype"),url("https://http2.mlstatic.com/frontend-assets/vis-web-navigation/ui-navigation/5.19.7/tucarro/navigation.woff2") format("woff2"),url("https://http2.mlstatic.com/frontend-assets/vis-web-navigation/ui-navigation/5.19.7/tucarro/navigation.woff") format("woff"),url("https://http2.mlstatic.com/frontend-assets/vis-web-navigation/ui-navigation/5.19.7/tucarro/navigation.ttf") format("truetype"),url("https://http2.mlstatic.com/frontend-assets/vis-web-navigation/ui-navigation/5.19.7/tucarro/navigation.svg#navigation") format("svg");font-weight:normal;font-style:normal}[class^=nav-icon-],[class*=" nav-icon-"]{font-style:normal}[class^=nav-icon-]:before,[class*=" nav-icon-"]:before{display:inline-block;font-variant:normal;margin:0;speak:none;text-align:center;width:1em;text-rendering:auto;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;font-family:"navigation"}.nav-icon-back-o:before,.nav-header .nav-header-btn:before{content:""}.nav-icon-bookmarks-o:before{content:""}.nav-icon-bookmarks:before{content:""}.nav-icon-chevron-right-o:before{content:""}.nav-icon-chevron-right:before{content:""}.nav-icon-chevron-up-o:before{content:""}.nav-icon-chevron-up:before{content:""}.nav-icon-close:before{content:""}.nav-icon-facebook:before{content:""}.nav-icon-gplus:before{content:""}.nav-icon-help-o:before{content:""}.nav-icon-help:before{content:""}.nav-icon-instagram:before{content:""}.nav-icon-login-o:before{content:""}.nav-icon-logout-o:before{content:""}.nav-icon-logout:before{content:""}.nav-icon-notifications-o:before{content:""}.nav-icon-notifications:before{content:""}.nav-icon-official-store-o:before{content:""}.nav-icon-register-o:before{content:""}.nav-icon-search-o:before{content:""}.nav-icon-search:before{content:""}.nav-icon-sell-o:before{content:""}.nav-icon-time-o:before{content:""}.nav-icon-twitter:before{content:""}.nav-icon-user-o:before{content:""}.nav-icon-user:before{content:""}.nav-icon-youtube:before{content:""}.nav-icon-close-o:before{content:""}.nav-icon-bookmarks-medium:before{content:""}.nav-icon-cart-empty-medium:before{content:""}.nav-icon-phone:before{content:""}.nav-icon-cart-empty-small:before{content:""}.nav-icon-cart-full-medium:before{content:""}.nav-icon-cart-full-small:before{content:""}.nav-icon-help-medium:before{content:""}.nav-icon-notifications-medium:before{content:""}.nav-icon-user-medium:before{content:""}.nav-icon-search-ml:before{content:""}.nav-icon-user-rounded:before{content:""}.nav-icon-app:before{content:""}.nav-icon-search-plus:before{content:""}.nav-icon-vender-mobile:before{content:""}.nav-icon-bookmarks-mobile:before{content:""}.nav-icon-categories-mobile:before{content:""}.nav-icon-create-account-mobile:before{content:""}.nav-icon-deals-mobile:before{content:""}.nav-icon-download-mobile:before{content:""}.nav-icon-help-mobile:before{content:""}.nav-icon-history-mobile:before{content:""}.nav-icon-logout-mobile:before{content:""}.nav-icon-my-account-mobile:before{content:""}.nav-icon-navigation-mobile:before{content:""}.nav-icon-notifications-mobile:before{content:""}.nav-icon-points-mobile:before{content:""}.nav-icon-purchases-mobile:before{content:""}.nav-icon-stores-mobile:before{content:""}.nav-icon-wallet-mobile:before{content:""}.nav-icon-contact-ms:before{content:""}.nav-icon-cart-ms:before{content:""}.nav-icon-close-ms:before{content:""}.nav-icon-search-ms:before{content:""}.nav-icon-search-spinner-ms:before{content:""}.nav-icon-twitter-ms:before{content:""}.nav-icon-facebook-ms:before{content:""}.nav-icon-instagram-ms:before{content:""}.nav-icon-points-discounts-mobile:before{content:""}.nav-icon-me ...
#   </style>
#   <link href="https://http2.mlstatic.com/frontend-assets/vpp-frontend/vip.motors.desktop.2eec7fc7.css" onerror="(window['_pfl'] = window['_pfl'] || []).push(['css', this.href])" rel="stylesheet" type="text/css"/>
#   <link href="https://http2.mlstatic.com/frontend-assets/vpp-frontend/insurtech.desktop.e863e1a7.css" onerror="(window['_pfl'] = window['_pfl'] || []).push(['css', this.href])" rel="stylesheet" type="text/css"/>
#   <script>
#    (function(win, doc) {
#
# function preloadCriticalPath() {
#   var head = doc.getElementsByTagName('head')[0],
#       assets = ["https://http2.mlstatic.com/frontend-assets/vis-web-navigation/ui-navigation/5.19.7/tucarro/navigation__v2.css"],
#       link,
#       i;
#   for(i = 0; i < assets.length; i++) {
#     link = doc.createElement('link');
#     link.rel = 'prefetch';
#     link.href = assets[i];
#     link.onerror = function(e) {
#       (window['_pfl'] = window['_pfl'] || []).push(['css', e.target.href]);
#     }
#     head.appendChild(link);
#   }
# }
#   if (doc.readyState === 'complete') {
#     setTimeout(preloadCriticalPath, 0);
#   } else {
#     win.addEventListener('load', function() {
#       preloadCriticalPath();
#     });
#   }
# })(window, document);
#   </script>
#   <script>
#    (function(a,b){a.GoogleAnalyticsObject=b;a[b]=a[b]||function(){(a[b].q=a[b].q||[]).push(arguments)};a[b].l=1*new Date})(window,"meli_ga");
# meli_ga("set", "title", "app-vpp-frontend-nodejs-3.3.1");
# meli_ga("set", "page", "/VIP/ITEM/MAIN/");
# meli_ga("set", "dimension9", "Continautos");
# meli_ga("set", "dimension19", "gold");
# meli_ga("set", "dimension20", "mercadolibre");
# meli_ga("set", "dimension23", "NEW_VIP");
# meli_ga("set", "dimension25", "{\"vis/similarFinancialCarousel\":\"17444\"}");
# meli_ga("set", "dimension35", "car_dealer");
# meli_ga("set", "dimension37", "not_specified");
# meli_ga("set", "dimension38", "classified");
# meli_ga("set", "dimension39", "active");
# meli_ga("set", "dimension40", "Banco De Bogota S.A.");
# meli_ga("set", "dimension43", "NO");
# meli_ga("set", "dimension47", "none");
# meli_ga("set", "dimension48", "[]");
# meli_ga("set", "dimension49", "MCO1268666883");
# meli_ga("set", "dimension51", "used");
# meli_ga("set", "dimension58", "brand");
# meli_ga("set", "dimension61", "NO");
# meli_ga("set", "dimension62", "NO");
# meli_ga("set", "dimension66", "NO");
# meli_ga("set", "dimension71", "silver");
# meli_ga("set", "dimension72", "none");
# meli_ga("set", "dimension73", "NO");
# meli_ga("set", "dimension75", "YES");
# meli_ga("set", "dimension83", "NO");
# meli_ga("set", "dimension86", "MCO-CARS_AND_VANS");
# meli_ga("set", "dimension90", "NONE");
# meli_ga("set", "dimension107", "No");
# meli_ga("set", "dimension111", "BRAND:Chevrolet, MODEL:Tracker");
# meli_ga("set", "dimension117", "VIP");
# meli_ga("set", "dimension118", "YES");
# meli_ga("set", "dimension119", "99473358");
# meli_ga("set", "dimension120", "Continautos");
# meli_ga("set", "dimension130", "MCO17047330");
# meli_ga("set", "dimension139", "Bogotá D.C.");
# meli_ga("set", "dimension140", "Fontibón");
# meli_ga("set", "dimension141", "Montevideo");
# meli_ga("set", "dimension3", "{'MCO1743':'Carros, Motos y Otros'}");
# meli_ga("set", "dimension4", "{'MCO1743':'Carros, Motos y Otros','MCO1744':'Carros y Camionetas'}");
# meli_ga("set", "contentGroup1", "/CLASSIFIED/VIP/ITEM/MAIN/");
# meli_ga("set", "contentGroup2", "/MOTORS/VIP/ITEM/MAIN/");
# meli_ga("set", "contentGroup3", "/NONE/VIP/ITEM/MAIN/");
# meli_ga("set", "dimension1", "desktop");
# meli_ga("set", "dimension7", "CLASSIFIED");
# meli_ga("set", "dimension8", "MOTORS");
# meli_ga("set", "dimension25", "{'vis/similarFinancialCarousel':'17444'}");
# meli_ga("send", "pageview");
# (function(d, win) {
#       win['GA-user-traceability-consent'] = true;
#       var i = d.createElement('iframe');
#       (i.frameElement || i).style.cssText = 'width: 0; height: 0; border: 0; position: absolute';
#       i.src = "about:srcdoc";
#       i.srcdoc="\<script\  src='https://http2.mlstatic.com/analytics/ga/mco-tc-analytics.min.js'>\</script\>";
#       i.id = "GoogleAnalyticsIframe";
#       var w = d.getElementsByTagName('script')[0];
#       w.parentNode.insertBefore(i, w);
#       var doc = i.contentWindow.document;
#       var s = doc.createElement('script');
#       s.type = 'text/javascript';
#       s.text ='window.inDapIF = true;';
#       doc.documentElement.appendChild(s);
#     })(document, window);
#   </script>
#  </head>
#  <style>
#   *:focus {
#     box-shadow: 0 0 0 2px #fff, 0 0 0 3px #2968C8, 0 0 0 5px rgba(65, 137, 230, 0.3);
#     outline: none;
#   }
#
#   *:focus-visible {
#     box-shadow: 0 0 0 2px #fff, 0 0 0 3px #2968C8, 0 0 0 5px rgba(65, 137, 230, 0.3);
#     outline: none;
#   }
#
#   *:focus:not(:focus-visible) {
#     box-shadow: none;
#     outline: none;
#   }
#  </style>
#  <body data-country="CO" data-site="TC">
#   <input id="nav-header-menu-switch" type="checkbox"/>
#   <header class="nav-header nav-header-full" data-siteid="MCO" role="banner">
#    <div class="nav-bounds">
#     <a class="nav-logo" href="//www.tucarro.com.co" tabindex="2">
#      TuCarro Colombia
#     </a>
#     <form action="https://www.tucarro.com.co/jm/search" class="nav-search" method="GET" role="search">
#      <input autocapitalize="off" autocomplete="off" autocorrect="off" class="nav-search-input" maxlength="120" name="as_word" spellcheck="false" tabindex="3" type="text"/>
#      <button class="nav-search-btn" tabindex="4" type="submit">
#       <div class="nav-icon-search" role="img">
#       </div>
#      </button>
#     </form>
#     <div class="nav-header-menu-wrapper">
#      <label aria-controls="nav-header-menu" for="nav-header-menu-switch">
#       <span class="hamburger-top-bread">
#       </span>
#       <span class="hamburger-patty">
#       </span>
#       <span class="hamburger-bottom-bread">
#       </span>
#      </label>
#      <nav class="nav-header-menu-mobile-guest" id="nav-header-menu-mobile">
#       <div id="nav-header-menu-mobile-content">
#        <div class="nav-header-menu-mobile-guest" id="nav-header-menu-mobile-user-info">
#         <div class="nav-header-menu-mobile-guest-logo">
#          <svg class="nav-header-menu-mobile-guest-icon" height="35" width="28" xmlns="http://www.w3.org/2000/svg">
#           <path d="M27.343 33.706l-1.356.64A13.25 13.25 0 0 0 14 26.75c-5.17 0-9.8 2.988-11.978 7.578l-1.356-.643A14.75 14.75 0 0 1 14 25.25a14.75 14.75 0 0 1 13.343 8.456zM14 21.75C8.063 21.75 3.25 16.937 3.25 11S8.063.25 14 .25 24.75 5.063 24.75 11 19.937 21.75 14 21.75zm0-1.5a9.25 9.25 0 1 0 0-18.5 9.25 9.25 0 0 0 0 18.5zm0-2.5v-1.5a5.25 5.25 0 1 0 0-10.5v-1.5a6.75 6.75 0 0 1 0 13.5z" fill="#BBB" fill-rule="nonzero">
#           </path>
#          </svg>
#         </div>
#         <h3 class="nav-header-menu-mobile-guest-title">
#         </h3>
#         <p class="nav-header-menu-mobile-guest-text">
#          Ingresa tu cuenta para publicar, hacer preguntas y más.
#         </p>
#         <div class="nav-header-menu-mobile-guest-buttons">
#          <a class="nav-mobile-button nav-mobile-button-filled" href="https://www.mercadolibre.com/jms/mco/lgz/login?platform_id=TC&amp;go=https%3A%2F%2Farticulo.tucarro.com.co%2FMCO-1268666883-chevrolet-tracker-ltz-mod-2019-4x4-aut-_JM&amp;loginType=explicit" rel="nofollow">
#           Ingresa
#          </a>
#          <a class="nav-mobile-button nav-mobile-button-outline" href="https://registration.tucarro.com.co/registration-tc?confirmation_url=https%3A%2F%2Farticulo.tucarro.com.co%2FMCO-1268666883-chevrolet-tracker-ltz-mod-2019-4x4-aut-_JM" rel="nofollow">
#           Crea tu cuenta
#          </a>
#         </div>
#        </div>
#        <ul>
#         <li>
#          <a href="https://www.tucarro.com.co/#menu-user">
#           <i class="nav-icon-home">
#           </i>
#           <span>
#            Inicio
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="https://www.tucarro.com.co/publica-tu-carro#menu-user">
#           <i class="nav-icon-vender-mobile">
#           </i>
#           <span>
#            Publica tu vehículo
#           </span>
#          </a>
#         </li>
#        </ul>
#        <ul>
#         <li>
#          <a href="https://www.tucarro.com.co/contactanos#menu-user">
#           <i class="nav-icon-contact-tc">
#           </i>
#           <span>
#            Contacto
#           </span>
#          </a>
#         </li>
#        </ul>
#        <ul>
#         <li>
#          <a href="https://www.tucarro.com.co/preguntas-frecuentes#menu-user">
#           <i class="nav-icon-help-mobile">
#           </i>
#           <span>
#            Ayuda / PQR
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </nav>
#      <nav id="nav-header-menu">
#       <a class="option-register" href="https://registration.tucarro.com.co/registration-tc?confirmation_url=https%3A%2F%2Farticulo.tucarro.com.co%2FMCO-1268666883-chevrolet-tracker-ltz-mod-2019-4x4-aut-_JM#nav-header" rel="nofollow" tabindex="8">
#        Crea tu cuenta
#       </a>
#       <a class="option-login" href="https://www.mercadolibre.com/jms/mco/lgz/login?platform_id=TC&amp;go=https%3A%2F%2Farticulo.tucarro.com.co%2FMCO-1268666883-chevrolet-tracker-ltz-mod-2019-4x4-aut-_JM&amp;loginType=explicit#nav-header" rel="nofollow" tabindex="8">
#        Ingresa
#       </a>
#       <a class="option-help" href="https://www.tucarro.com.co/preguntas-frecuentes#nav-header" rel="nofollow" tabindex="8">
#        Ayuda / PQR
#       </a>
#       <a class="option-helpContact" href="https://www.tucarro.com.co/contactanos#nav-header" rel="nofollow" tabindex="8">
#        Contacto
#       </a>
#       <a class="option-publish" href="https://www.tucarro.com.co/publica-tu-carro#nav-header" rel="nofollow" tabindex="8">
#        Publica tu vehículo
#       </a>
#      </nav>
#     </div>
#    </div>
#   </header>
#   <main id="root-app" role="main">
#    <div class="ui-vip-core ui-vip-core--official-store">
#     <div style="display:contents">
#      <svg class="ui-vpp-svg-sprites" data-reactroot="" style="display:none" xmlns="http://www.w3.org/2000/svg">
#       <defs>
#        <symbol id="loyalty_points">
#         <path d="M7.598 8.746v1.252h.6c1.657 0 3 1.343 3.001 3v.6H2.798v-.602a2.998 2.998 0 0 1 2.998-2.997h.604l-.001-1.253a3.435 3.435 0 0 1-1.578-.724l-1.586-.446-.106-.041-.739-.37A3.6 3.6 0 0 1 .402 3.947V1.599h2.486l-.2-1.2h8.618l-.2 1.2h2.489v2.346a3.6 3.6 0 0 1-1.988 3.22l-.739.37-.106.041-1.592.448a3.43 3.43 0 0 1-1.572.722zm2.65-2.272l.134-.037.688-.345a2.4 2.4 0 0 0 1.326-2.147V2.799h-1.49l-.52 3.13c-.032.187-.078.37-.138.545zm-6.505-.001a3.453 3.453 0 0 1-.139-.552L3.087 2.8H1.602v1.148a2.4 2.4 0 0 0 1.325 2.145l.687.345.129.036zm.361-4.874l.684 4.126a2.24 2.24 0 0 0 2.21 1.874c1.092 0 2.024-.79 2.204-1.868L9.89 1.6H4.104zm4.094 9.6H5.795c-.784 0-1.45.5-1.697 1.199h5.799c-.248-.699-.915-1.2-1.7-1.2z" fill-rule="nonzero">
#         </path>
#        </symbol>
#       </defs>
#       <defs>
#        <symbol id="protected_buy">
#         <path d="M.399 3.89v-.6h.6c1.87 0 3.76-.783 5.68-2.374l.383-.317.383.317c1.92 1.59 3.81 2.374 5.68 2.374h.6v.6c0 5.633-2.165 9.242-6.473 10.679l-.19.063-.19-.063C2.564 13.132.4 9.523.4 3.89zm6.663-1.743c-1.8 1.4-3.62 2.179-5.455 2.32.135 4.725 1.947 7.648 5.455 8.898 3.508-1.25 5.32-4.173 5.455-8.898-1.835-.141-3.656-.92-5.455-2.32zm-.905 6.477l3.191-3.582.896.798-4.02 4.513-2.472-2.377.831-.865 1.574 1.513z" fill-rule="nonzero">
#         </path>
#        </symbol>
#       </defs>
#       <defs>
#        <symbol id="returns">
#         <path d="M2.474 7.2h7.225a2.7 2.7 0 1 0 0-5.4H7V.6h2.7a3.9 3.9 0 1 1 0 7.8H2.473l2.45 2.389-.839.859L.14 7.8l3.945-3.848.838.859L2.473 7.2z">
#         </path>
#        </symbol>
#       </defs>
#       <defs>
#        <symbol id="warranty">
#         <path d="M5.305 10.354l-1.686 3.34-1.24-2.458H0l1.64-3.202a5.2 5.2 0 1 1 8.588.194l1.54 3.008H9.39l-1.241 2.458-1.673-3.315a5.266 5.266 0 0 1-1.171-.025zm-1.001-.237a5.201 5.201 0 0 1-1.975-1.234l-.693 1.353h1.357l.626 1.239.685-1.358zm3.192.064l.653 1.294.625-1.239h1.358l-.617-1.204a5.193 5.193 0 0 1-2.019 1.15zM6 9.2a4 4 0 1 0 0-8 4 4 0 0 0 0 8z" fill-rule="nonzero">
#         </path>
#        </symbol>
#       </defs>
#       <defs>
#        <symbol id="sharegallery">
#         <g fill="none" fill-rule="evenodd">
#          <circle cx="20" cy="20" fill="#F5F5F5" r="20">
#          </circle>
#          <g transform="translate(9 10)">
#           <path d="M7.565 11.848a3.002 3.002 0 1 1 0-3.707l4.337-2.173a3.006 3.006 0 0 1 2.9-3.783 3.002 3.002 0 1 1-2.362 4.856L8.102 9.214a3.006 3.006 0 0 1 0 1.562l4.337 2.17a3.002 3.002 0 1 1-.537 1.073l-4.337-2.17zm-2.363-.05a1.802 1.802 0 1 0 0-3.605 1.802 1.802 0 0 0 0 3.604zm9.6 4.802a1.802 1.802 0 1 0 0-3.605 1.802 1.802 0 0 0 0 3.605zm0-9.61a1.802 1.802 0 1 0 0-3.605 1.802 1.802 0 0 0 0 3.605z" fill="#333" fill-rule="nonzero">
#           </path>
#          </g>
#         </g>
#        </symbol>
#       </defs>
#       <defs>
#        <symbol id="loyalty_trophy_rounded">
#         <path d="M24 0c13.255 0 24 10.745 24 24S37.255 48 24 48 0 37.255 0 24 10.745 0 24 0zm6.885 14.25H17.114l.169 1.01-3.033-.05v4.011a5.75 5.75 0 0 0 3.057 5.08l5.942 3.15v1.799H21A3.75 3.75 0 0 0 17.25 33v.75h13.5V33A3.75 3.75 0 0 0 27 29.25h-2.25v-1.799l5.943-3.15a5.75 5.75 0 0 0 3.058-5.08v-4.01l-3.034.05.169-1.011zm-3.886 16.5c.98 0 1.814.626 2.122 1.5H18.877A2.25 2.25 0 0 1 21 30.75zm2.115-15l-.908 5.459a5.49 5.49 0 0 1-2.371 3.667l-1.142.76c-.42.28-.967.28-1.387 0l-1.14-.76a5.492 5.492 0 0 1-2.371-3.666l-.91-5.46h10.23zm-13.364.986l1.783.029.782 4.691c.12.718.35 1.405.675 2.04l-.98-.52a4.25 4.25 0 0 1-2.26-3.755v-2.485zm16.5 0v2.485a4.25 4.25 0 0 1-2.26 3.755l-.979.519a6.988 6.988 0 0 0 .674-2.04l.781-4.69 1.784-.03z" fill-rule="evenodd">
#         </path>
#        </symbol>
#       </defs>
#       <defs>
#        <symbol id="rounded_truck_medium_alt">
#         <path d="M15 29.75C6.867 29.75 0.25 23.133 0.25 15C0.25 6.867 6.867 0.25 15 0.25c8.133 0 14.75 6.617 14.75 14.75 C29.75 23.133 23.133 29.75 15 29.75z M15 1.25C7.418 1.25 1.25 7.418 1.25 15c0 7.582 6.168 13.75 13.75 13.75 c7.582 0 13.75-6.168 13.75-13.75C28.75 7.418 22.582 1.25 15 1.25z" stroke="#00a650" stroke-width="0.5">
#         </path>
#         <path d="M14.29 19.292c-0.297 0.985-1.212 1.702-2.293 1.702c-1.083 0-1.997-0.719-2.294-1.703L9.001 19.29 c-0.994 0-1.8-0.806-1.8-1.8v-6.695c0-0.994 0.806-1.8 1.8-1.8h6.664c0.994 0 1.8 0.806 1.8 1.8V10.8h2.626l2.708 3.491v4.999 l-1.846 0.002c-0.297 0.985-1.211 1.702-2.293 1.702s-1.996-0.717-2.293-1.702H14.29z M18.66 17.405 c-0.66 0-1.195 0.534-1.195 1.194S18 19.794 18.66 19.794s1.195-0.535 1.195-1.194C19.855 17.939 19.32 17.405 18.66 17.405z M11.997 17.405c-0.66 0-1.195 0.534-1.195 1.194s0.535 1.194 1.195 1.194s1.194-0.535 1.194-1.194 C13.191 17.939 12.656 17.405 11.997 17.405z M15.665 10.195H9.001c-0.331 0-0.6 0.269-0.6 0.6v6.695c0 0.33 0.269 0.6 0.6 0.6 h0.655c0.234-1.078 1.193-1.885 2.34-1.885c1.148 0 2.107 0.807 2.34 1.884h1.93v-7.294C16.266 10.464 15.996 10.195 15.665 10.195 L15.665 10.195z M19.503 12h-2.038v4.525c0.352-0.205 0.76-0.32 1.195-0.32c1.146 0 2.105 0.807 2.34 1.885h0.6v-3.388L19.503 12z">
#         </path>
#        </symbol>
#       </defs>
#       <defs>
#        <symbol id="arrow">
#         <g fill="none" fill-rule="evenodd" stroke="#3483FA" stroke-width="1.5">
#          <path d="M9 1.458L1.458 9 9 16.542M1.667 9h14.666">
#          </path>
#         </g>
#        </symbol>
#       </defs>
#       <defs>
#        <symbol id="bookmark">
#         <path d="M10.977 2.705C11.93 1.618 13.162 1 14.895 1c3.333 0 5.607 2.152 5.607 6.274 0 .08-.002.16-.005.24-.107 2.596-1.876 5.253-4.737 7.892a33.77 33.77 0 0 1-3.165 2.57 32.447 32.447 0 0 1-1.45.983l-.394.243-.394-.243-.009-.005-.021-.014-.08-.05a32.447 32.447 0 0 1-1.34-.914 33.77 33.77 0 0 1-3.165-2.57c-2.86-2.639-4.63-5.296-4.737-7.892A5.839 5.839 0 0 1 1 7.274C1 3.152 3.274 1 6.607 1c1.733 0 2.966.618 3.918 1.705.056.064.137.165.226.282.09-.117.17-.218.226-.282z" stroke="#3483FA">
#         </path>
#        </symbol>
#       </defs>
#       <defs>
#        <symbol id="cart">
#         <g fill="none" fill-rule="evenodd">
#          <rect fill="#EEE" height="48" rx="24" width="48">
#          </rect>
#          <path d="M20.7 29.78c.82 0 1.485.665 1.485 1.485 0 .82-.665 1.485-1.485 1.485-.82 0-1.485-.664-1.485-1.484s.665-1.485 1.485-1.485zm8.58 0c.82 0 1.485.665 1.485 1.485 0 .82-.665 1.485-1.485 1.485-.82 0-1.485-.664-1.485-1.484s.665-1.485 1.485-1.485zM17.957 15.415l.449 2.64h14.981L31.134 28.62H18.861l-2.018-11.886H14.1v-1.32h3.857zm13.799 3.96H18.63l1.345 7.926h10.09l1.69-7.926z" fill="#000" fill-opacity=".8" fill-rule="nonzero">
#          </path>
#         </g>
#        </symbol>
#       </defs>
#       <defs>
#        <symbol id="cbt">
#         <path d="M7.82379019,9.12714784 L4.43792691,5.99590227 C3.78263916,5.38989232 3.97046599,4.48046833 4.81277096,4.17293706 L5.16058339,4.04594838 C5.72378314,3.84032032 6.56217535,3.86133538 7.11802392,4.09520049 L11.4022736,5.89773552 L12.7880957,4.66558836 C13.1778546,4.31905009 13.8428025,3.9191166 14.2997555,3.74785669 C14.3689667,3.71659935 14.4840452,3.66870611 14.6337725,3.6131018 C14.8823805,3.52077609 15.1417396,3.43961734 15.4022372,3.37879628 C16.2668778,3.17691973 16.9710204,3.21820417 17.432435,3.72276691 C17.8947528,4.22831745 17.8628258,4.92493622 17.5683309,5.75415812 C17.4797935,6.00345668 17.3709072,6.24951851 17.2519096,6.48386727 C17.1802425,6.62500545 17.1199706,6.73294501 17.1040728,6.75580798 C16.8751184,7.21804262 16.3953523,7.83367578 15.9985724,8.18645647 L14.6083475,9.42251822 L15.8678759,13.6809197 C16.0295563,14.2275531 16.0217151,15.0227985 15.8504049,15.5541493 L15.684667,16.0682164 C15.3984618,16.9559355 14.4523064,17.0945952 13.8861485,16.3593166 L10.9930788,12.6020393 C10.365527,13.0838536 9.57559135,13.5924917 8.95770967,13.9028379 L9.25251262,15.3455225 C9.34618272,15.8039181 9.31488122,16.4556731 9.18455502,16.9585192 C9.18386395,16.9988877 9.1695401,17.0335511 9.15417897,17.0669949 C9.14034457,17.112778 9.12562323,17.156971 9.1100376,17.1992752 C8.70818639,17.8331114 7.90274515,17.9178817 7.35579039,17.3180469 L2.54080803,12.0375484 C1.97157154,11.4132776 2.17737862,10.6082919 2.92239198,10.3487238 C2.95448673,10.3289421 2.99029478,10.3225773 3.02703045,10.3168491 C3.0546449,10.3095884 3.08289956,10.3030282 3.11178447,10.2971991 C3.63528539,10.2395989 4.31092762,10.2928356 4.77342413,10.442426 L6.34631124,10.9511623 C6.70532975,10.4343333 7.30342006,9.68418064 7.82379019,9.12714784 Z M5.38827956,5.2402954 L9.52399862,9.06500743 L8.70068512,9.94632748 C8.24461354,10.4345316 7.67913597,11.1358494 7.33185741,11.6357781 L6.82399761,12.3668733 L4.40413105,11.5841889 C4.21539151,11.5231428 3.93110672,11.4837554 3.65265685,11.4759086 L8.08266356,16.3342117 C8.11627758,16.0618378 8.11520942,15.7736955 8.07680807,15.5857698 L7.59805685,13.2428931 L8.41910312,12.8305026 C8.95565569,12.561006 9.68143635,12.0961874 10.2623009,11.6502181 L11.2127933,10.9204603 L14.6459836,15.3792012 L14.708296,15.1859276 C14.8052804,14.885112 14.8104815,14.3368067 14.7171549,14.0212741 L13.2414797,9.03209136 L15.2012254,7.2896634 C15.4894681,7.03338416 15.8720623,6.53952691 16.028755,6.22318086 L16.1188488,6.07072865 C16.0943334,6.10598462 16.143793,6.01570138 16.1819473,5.94056193 C16.2843256,5.73894258 16.3706034,5.54099774 16.4375272,5.35255768 C16.6256619,4.82281849 16.6175454,4.60985052 16.5468878,4.53258557 C16.4697391,4.44822247 16.2389733,4.41570871 15.6750756,4.54736772 C15.4765818,4.59371211 15.2666841,4.65813485 15.051539,4.73803342 C14.9417786,4.77879519 14.8485541,4.81670981 14.7208935,4.8715305 C14.3972267,4.99283647 13.8607384,5.31761338 13.5854426,5.56238143 L11.6342369,7.29721634 L6.65265685,5.20128843 C6.3756357,5.08473719 5.8504911,5.07153883 5.57213864,5.1731672 L5.38827956,5.2402954 Z" id="🎨Icon-color">
#         </path>
#        </symbol>
#       </defs>
#       <defs>
#        <symbol id="check_circle">
#         <path d="M6.788 9.396L11.365 4.819 12.393 5.848 6.788 11.453 3.607 8.272 4.635 7.243z" fill="#FFF">
#         </path>
#        </symbol>
#       </defs>
#       <defs>
#        <symbol id="chevron">
#         <path d="M1 1.343L6.657 7 1 12.657" fill="none" fill-rule="evenodd" stroke-width="1.5">
#         </path>
#        </symbol>
#       </defs>
#       <defs>
#        <symbol id="close">
#         <path d="M1.06 0l6.003 6.003L13.061.007l1.06 1.06-5.997 5.997 5.997 5.997-1.06 1.06-5.997-5.997-6.003 6.004L0 13.068l6.003-6.004L0 1.061 1.06 0z" fill-opacity=".8" fill-rule="evenodd">
#         </path>
#        </symbol>
#       </defs>
#       <defs>
#        <symbol id="express">
#         <g fill-rule="evenodd">
#          <circle cx="24" cy="24" fill-opacity=".07" r="24">
#          </circle>
#          <path d="M29.354 14.75c1.243 0 2.25 1.007 2.25 2.25 0 .263-.046.523-.136.77l-.54 1.48h2.613l1.757 5.273L33.508 29h-2.859c-.333 1.294-1.507 2.25-2.906 2.25-1.398 0-2.572-.956-2.905-2.25h-4.68c-.333 1.294-1.507 2.25-2.906 2.25-1.657 0-3-1.343-3-3 0-.547.146-1.06.401-1.5l-1.903-.001v-1.5h5.252v.095c1.055.271 1.885 1.1 2.156 2.155h4.68c.282-1.097 1.17-1.95 2.284-2.186l2.937-8.056c.03-.083.045-.17.045-.257 0-.414-.336-.75-.75-.75H17.25v-1.5zM17.253 26.749c-.83 0-1.501.672-1.501 1.5 0 .83.672 1.501 1.5 1.501.83 0 1.501-.672 1.501-1.5 0-.83-.672-1.501-1.5-1.501zm10.49 0c-.828 0-1.5.672-1.5 1.5 0 .83.672 1.501 1.5 1.501.83 0 1.501-.672 1.501-1.5 0-.83-.672-1.501-1.5-1.501zm4.716-5.999h-2.078l-1.693 4.65c.961.32 1.707 1.11 1.961 2.1h1.843l1.21-3.023-1.243-3.727zm-13.709 0v1.5h-6v-1.5h6zm4.502-3v1.5h-7.499v-1.5h7.499z" fill-opacity=".8" fill-rule="nonzero">
#          </path>
#         </g>
#        </symbol>
#       </defs>
#       <defs>
#        <symbol id="facing">
#         <g fill="#111" fill-rule="nonzero" transform="translate(1 1)">
#          <path d="M7.052 13.97c3.894 0 7.051-3.127 7.051-6.985C14.103 3.127 10.946 0 7.052 0 3.157 0 0 3.127 0 6.985c0 3.858 3.157 6.986 7.052 6.986zM6.582.95v1.378c0 .258.21.466.47.466s.47-.208.47-.466V.95c2.914.223 5.261 2.46 5.599 5.337h-1.368c-.26 0-.47.208-.47.466 0 .257.21.465.47.465h1.41c-.12 3.073-2.546 5.569-5.641 5.803v-1.146a.468.468 0 0 0-.47-.465c-.26 0-.47.208-.47.465v1.146C3.486 12.787 1.06 10.29.94 7.218h1.175c.26 0 .47-.208.47-.465a.468.468 0 0 0-.47-.466H.983C1.32 3.41 3.667 1.173 6.582.95z">
#          </path>
#          <path d="M5.49 8.368a.47.47 0 0 0 .21.208l4.66 2.313c.181.089.4.053.543-.088a.464.464 0 0 0 .09-.538L8.656 5.647a.47.47 0 0 0-.21-.208l-4.66-2.313a.475.475 0 0 0-.542.088.464.464 0 0 0-.09.538L5.49 8.368zm2.396-2.163l1.63 3.22-3.252-1.613-1.628-3.22 3.25 1.613z">
#          </path>
#          <ellipse cx="7.075" cy="7.009" rx="1" ry="1">
#          </ellipse>
#         </g>
#        </symbol>
#       </defs>
#       <defs>
#        <symbol id="fast_truck">
#         <path d="M10.587 14.805H7.01a2.452 2.452 0 1 1-4.452-1.937l-1.56-.003.002-1.2 3.6.008v.025h.048c1.167 0 2.143.815 2.39 1.907h3.52a2.455 2.455 0 0 1 1.836-1.844l2.423-6.352a.6.6 0 0 0-.56-.814H4.6v-1.2h9.658a1.8 1.8 0 0 1 1.697 2.4h1.677l1.409 4.225-2.027 4.787-1.701-.007a2.452 2.452 0 0 1-4.726.005zm4.751-1.205l.883.004 1.538-3.634-.991-2.975h-1.27l-1.835 4.809c.834.253 1.48.939 1.675 1.796zM7 5.79v1.2H1v-1.2h6zM4.6 8.222v1.2H2.2v-1.2h2.4zm.049 7.178a1.251 1.251 0 1 0 0-2.502 1.251 1.251 0 0 0 0 2.502zm8.3 0a1.251 1.251 0 1 0 0-2.502 1.251 1.251 0 0 0 0 2.502z" fill-rule="nonzero">
#         </path>
#        </symbol>
#       </defs>
#       <defs>
#        <symbol id="full_icon">
#         <path d="M2.628 0h5.255L5.255 4.643h4.38L2.628 13l1.751-5.571H0L2.628 0zm11.589 9.533h-1.959l1.674-7.515H19.5l-.376 1.69h-3.61l-.25 1.172h3.519l-.376 1.69h-3.53l-.66 2.963zm9.468.136c-2.334 0-3.484-1.105-3.484-2.682 0-.124.034-.383.057-.496l1.002-4.473h1.992l-.99 4.428c-.012.057-.034.18-.034.316.011.62.49 1.217 1.457 1.217 1.048 0 1.583-.654 1.776-1.533l.991-4.428h1.981l-.99 4.462c-.41 1.825-1.412 3.189-3.758 3.189zm10.118-.136h-5.01l1.673-7.515h1.959l-1.287 5.825h3.04l-.375 1.69zm6.678 0h-5.01l1.674-7.515h1.959l-1.287 5.825h3.04l-.376 1.69z" fill-rule="nonzero">
#         </path>
#        </symbol>
#       </defs>
#       <defs>
#        <symbol id="help">
#         <path d="M17.216 0c8.836 0 16 7.164 16 16s-7.164 16-16 16-16-7.164-16-16 7.164-16 16-16zM17.216 2.133c-7.659 0-13.867 6.208-13.867 13.867s6.208 13.867 13.867 13.867 13.867-6.208 13.867-13.867-6.208-13.867-13.867-13.867zM17.257 21.44c1.013 0 1.867 0.853 1.867 1.867s-0.853 1.867-1.867 1.867c-1.013 0-1.867-0.853-1.867-1.867s0.853-1.867 1.867-1.867zM17.417 6.827c3.36 0 5.413 1.787 5.413 4.187 0 2.213-1.493 3.28-2.827 4.213-1.013 0.747-1.947 1.387-1.947 2.453 0 0.427 0.24 0.907 0.587 1.2l-2.347 0.773c-0.64-0.613-0.96-1.387-0.96-2.267 0-1.787 1.28-2.693 2.427-3.52 0.987-0.693 1.867-1.307 1.867-2.347s-0.8-1.92-2.533-1.92c-1.627 0-2.8 0.747-3.707 1.867l-1.787-2c1.36-1.653 3.413-2.64 5.813-2.64z" fill-rule="evenodd">
#         </path>
#        </symbol>
#       </defs>
#       <defs>
#        <symbol id="card">
#         <path d="M17.8 7.61V5.8a.6.6 0 0 0-.6-.6H2.8a.6.6 0 0 0-.6.6v1.81h15.6zm0 1.2H2.2v5.39a.6.6 0 0 0 .6.6h14.4a.6.6 0 0 0 .6-.6V8.81zM2.8 4h14.4A1.8 1.8 0 0 1 19 5.8v8.4a1.8 1.8 0 0 1-1.8 1.8H2.8A1.8 1.8 0 0 1 1 14.2V5.8A1.8 1.8 0 0 1 2.8 4zm1.195 8.996l.002-1.2 4.204.007-.002 1.2-4.204-.007z" fill-rule="nonzero">
#         </path>
#        </symbol>
#       </defs>
#       <defs>
#        <symbol id="location_alt">
#         <path d="M10 1c3.505 0 6.347 2.842 6.347 6.347 0 3.043-1.975 6.838-5.89 11.432l-.457.536-.457-.536c-3.915-4.594-5.89-8.389-5.89-11.432C3.653 3.842 6.495 1 10 1zm0 1.2c-2.843 0-5.147 2.304-5.147 5.147 0 2.578 1.706 5.963 5.147 10.11 3.441-4.147 5.147-7.532 5.147-10.11C15.147 4.504 12.843 2.2 10 2.2zm0 2.985c1.331 0 2.41 1.079 2.41 2.41 0 1.331-1.079 2.41-2.41 2.41-1.331 0-2.41-1.079-2.41-2.41 0-1.331 1.079-2.41 2.41-2.41zm0 1.2c-.668 0-1.21.542-1.21 1.21 0 .668.542 1.21 1.21 1.21.668 0 1.21-.542 1.21-1.21 0-.668-.542-1.21-1.21-1.21z">
#         </path>
#        </symbol>
#       </defs>
#       <defs>
#        <symbol id="meli_coins">
#         <path d="M14.7803 7.49999C14.7803 3.47921 11.5208 0.219717 7.5 0.219717C3.47921 0.219717 0.219726 3.47921 0.219726 7.5C0.219726 11.5208 3.47921 14.7803 7.5 14.7803C11.5208 14.7803 14.7803 11.5208 14.7803 7.49999Z" fill="#FCEE56">
#         </path>
#         <path d="M2.10644 2.61002C3.39879 1.43753 5.11427 0.723064 6.99665 0.723064C11.0174 0.723064 14.2769 3.98255 14.2769 8.00334C14.2769 9.88573 13.5625 11.6012 12.39 12.8936C13.8581 11.5616 14.78 9.63861 14.78 7.50023C14.78 3.47943 11.5206 0.219948 7.49977 0.219948C5.36139 0.219948 3.43837 1.14192 2.10644 2.61002V2.61002Z" fill="#FBD307">
#         </path>
#         <path d="M1.66077 3.1513L13.5306 11.5798C13.089 12.2312 12.5448 12.8071 11.9212 13.2842L0.580566 5.23149C0.827685 4.47596 1.19554 3.77515 1.66077 3.1513V3.1513Z" fill="#FBF4AF">
#         </path>
#         <path d="M13.4189 7.50001C13.4189 4.23107 10.7689 1.58107 7.49999 1.58107C4.23105 1.58107 1.58105 4.23107 1.58105 7.50001C1.58105 10.7689 4.23105 13.4189 7.49999 13.4189C10.7689 13.4189 13.4189 10.7689 13.4189 7.50001Z" fill="#E6B700">
#         </path>
#         <path d="M12.7975 7.50042C12.7975 4.57472 10.4258 2.20298 7.50007 2.20298C4.57438 2.20298 2.20264 4.57472 2.20264 7.50042C2.20264 10.4261 4.57438 12.7979 7.50007 12.7979C10.4258 12.7979 12.7975 10.4261 12.7975 7.50042Z" fill="url(#paint0_linear_183:55615)">
#         </path>
#         <path d="M11.7427 11.7427C12.8759 10.6094 13.5 9.10265 13.5 7.5C13.5 6.09644 13.0052 4.73116 12.1069 3.65571C12.0446 3.5812 11.9338 3.57126 11.8593 3.63351C11.7847 3.69572 11.7748 3.80658 11.837 3.88111C12.6827 4.89344 13.1484 6.17866 13.1484 7.5C13.1484 10.6146 10.6146 13.1484 7.5 13.1484C4.38543 13.1484 1.85156 10.6146 1.85156 7.5C1.85156 4.38543 4.38543 1.85156 7.5 1.85156C8.90062 1.85156 10.2441 2.36789 11.283 3.30544C11.355 3.37045 11.4662 3.36476 11.5312 3.29269C11.5962 3.22069 11.5906 3.10952 11.5185 3.04444C10.4149 2.04848 8.98779 1.5 7.5 1.5C5.89734 1.5 4.39061 2.12411 3.25734 3.25734C2.12411 4.39059 1.5 5.89734 1.5 7.5C1.5 9.10265 2.12411 10.6094 3.25734 11.7427C4.39061 12.8759 5.89734 13.5 7.5 13.5C9.10265 13.5 10.6094 12.8759 11.7427 11.7427Z" fill="#9D7100">
#         </path>
#         <path d="M2.19668 2.19668C0.780143 3.61324 -2.74477e-06 5.49668 -2.16617e-06 7.5C-1.65945e-06 9.25444 0.618456 10.961 1.74143 12.3054C1.81922 12.3985 1.95779 12.4109 2.05093 12.3331C2.14406 12.2554 2.15651 12.1168 2.0787 12.0236C1.02161 10.7582 0.439451 9.15167 0.439451 7.5C0.43945 3.6068 3.60679 0.439453 7.49999 0.439453C11.3932 0.439453 14.5605 3.6068 14.5605 7.5C14.5605 11.3932 11.3932 14.5605 7.5 14.5605C5.74922 14.5605 4.06986 13.9151 2.77128 12.7432C2.68119 12.6619 2.54224 12.6691 2.46094 12.7591C2.3797 12.8491 2.3867 12.9881 2.47684 13.0695C3.85635 14.3144 5.64026 15 7.5 15C9.50332 15 11.3867 14.2199 12.8033 12.8033C14.2198 11.3868 15 9.50332 15 7.5C15 5.49668 14.2198 3.61324 12.8033 2.19668C11.3867 0.780146 9.50331 1.7555e-07 7.49999 1.88803e-07C5.49667 2.02056e-07 3.61327 0.780146 2.19668 2.19668V2.19668Z" fill="#9D7100">
#         </path>
# ...
#               function(id) {
#                   clearTimeout(id);
#               };
#             window.__PRELOADED_STATE__ = {"translations":{},"initialState":{"id":"MCO1268666883","vip_filters":null,"layout":"vip-motors-tucarro","vertical":"motors","components_locations":{"variations":"short_description"},"components":{"head":[],"content_right":[{"id":"price_comparison","type":"price_comparison","state":"VISIBLE","title":{"text":"Precios de referencia","color":"BLACK","font_size":"LARGE","font_family":"REGULAR"},"header_title":{"text":"Según los vendedores en Mercado Libre.","color":"BLACK","font_size":"XSMALL","font_family":"REGULAR"},"chart":{"lower_band":{"text":"$ 60.676.000","color":"BLACK","font_size":"XXSMALL","font_family":"REGULAR"},"upper_band":{"text":"$ 82.091.000","color":"BLACK","font_size":"XXSMALL","font_family":"REGULAR"},"price_distributions":[0.1,0.07,0.15,0.5,0.7,0.4,1,0.35],"tooltip":{"data":{"text":"$ 85.900.000","color":"WHITE","bg_color":"BLUE","font_size":"XSMALL","font_family":"SEMIBOLD","type":"SMALL_ROUNDED"},"pole_size":"SMALL","percentile_position":0.92}},"legend":{"title":{"text":"39.929 km","color":"BLACK","font_size":"MEDIUM","font_family":"REGULAR"},"subtitle":{"text":"Chevrolet | Tracker | 2019","color":"BLACK","font_size":"XXSMALL","font_family":"REGULAR"}},"actions":[{"id":"similar_vehicles","target":"https:\u002F\u002Fcarros.tucarro.com.co\u002Fchevrolet\u002Ftracker\u002F2019\u002F_PriceRange_60676000-82091000","timeout":0,"duration":0,"label":{"text":"Ver vehículos similares","font_size":"XSMALL","font_family":"REGULAR"},"track":{"melidata_event":{"path":"\u002Fvip\u002Fsimilar_vehicles","event_data":{"item_id":"MCO1268666883","listing_type_id":"gold","item_condition":"used","deal_ids":[],"category_id":"MCO1744","category_path":["MCO1743","MCO1744"],"vertical":"motors","item_status":"active","buying_mode":"classified","seller_id":99473358,"item_seller_type":"car_dealer","has_good_price":false,"has_highlighted_sale_specs":false,"verified":false,"bank":"Banco De Bogota S.A."}},"analytics_event":{"section":"\u002FVIP\u002FITEM\u002FMAIN\u002F","action":"SIMILAR_VEHICLES","category":"ITEM","label":"PRICE_COMPARISON_MOTORS","custom_dimensions":{"3":"{'MCO1743':'Carros, Motos y Otros'}","4":"{'MCO1743':'Carros, Motos y Otros','MCO1744':'Carros y Camionetas'}","7":"CLASSIFIED","8":"MOTORS","9":"Continautos","19":"gold","20":"mercadolibre","23":"NEW_VIP","35":"car_dealer","38":"classified","39":"active","47":"none","48":"[]","49":"MCO1268666883","51":"used","58":"brand","61":"NO","71":"silver","72":"none","83":"NO","86":"MCO-CARS_AND_VANS","107":"No","111":"BRAND:Chevrolet, MODEL:Tracker","117":"VIP","118":"YES","119":"99473358","120":"Continautos","139":"Bogotá D.C.","140":"Fontibón","141":"Montevideo"}}},"action_type":"LINK"}],"feedback_component":{"title":{"text":"¿La referencia de precios fue útil?"},"local_storage_key":"real_estate-price-comparison-feedback","actions":[{"text":"Sí","icon":"THUMB_UP","id":"up-vote","congrats":{"text":"Gracias por tu respuesta."},"track":{"melidata_event":{"path":"\u002Fvip\u002Ffeature_feedback","event_data":{"user_feedback":"up-vote","feature":"price-comparison","vertical":"motors","item_id":"MCO1268666883","category_id":"MCO1744"}},"analytics_event":{"section":"\u002FVIP\u002FITEM\u002FMAIN\u002F","action":"FEATURE_FEEDBACK","category":"ITEM","label":"UP-VOTE"}}},{"text":"No","icon":"THUMB_DOWN","id":"down-vote","congrats":{"text":"Gracias por tu respuesta, seguiremos mejorando."},"track":{"melidata_event":{"path":"\u002Fvip\u002Ffeature_feedback","event_data":{"user_feedback":"down-vote","feature":"price-comparison","vertical":"motors","item_id":"MCO1268666883","category_id":"MCO1744"}},"analytics_event":{"section":"\u002FVIP\u002FITEM\u002FMAIN\u002F","action":"FEATURE_FEEDBACK","category":"ITEM","label":"DOWN-VOTE"}}}]}},{"id":"external_credits","type":"external_credits","state":"VISIBLE","title":{"text":"Solicita tu crédito online","color":"BLACK","font_size":"MEDIUM","font_family":"REGULAR"},"subtitles":[{"char_icon":{"text":"•","co ...
#         }},{s:function(){/* eslint-disable no-restricted-syntax */
# /* eslint-disable guard-for-in */
# /* eslint-disable no-param-reassign */
# /* eslint-disable no-var */
# /* eslint-disable prefer-template */
# /* eslint-disable prefer-arrow-callback */
# /* eslint-disable vars-on-top */
# /* eslint-disable-next-line no-restricted-syntax */
# /* eslint-disable-next-line guard-for-in */
#
# (function () {
#   var defaults = {
#     imageLoadClassName: 'lazy-loadable', // 'lazy-loadable' || 'onload-loadable'
#     options: {
#       rootMargin: '360px',
#       loadMode: 'lazy', // 'lazy' || 'onload'
#     },
#   };
#   var dataSrcKey = 'data-src';
#   var dataSrcFallbackKey = 'data-src-fallback';
#   var dataSrcSetKey = 'data-srcset';
#
#   // IntersectionObserver has partial support in chrome <= 57 (https://caniuse.com/#feat=intersectionobserver)
#   var supportIntersectionObserver = 'IntersectionObserver' in window
#     && 'IntersectionObserverEntry' in window
#     && 'isIntersecting' in window.IntersectionObserverEntry.prototype;
#
#   function mergeOptions(target, source) {
#     var list = [target, source];
#     var cloned = {};
#
#     for (var i = 0; i <= list.length; i += 1) {
#       if (typeof list[i] === 'object' && list[i]) {
#         for (var prop in list[i]) {
#           cloned[prop] = list[i][prop];
#         }
#       }
#     }
#     return cloned;
#   }
#
#   function imageLazyLoading(imageLoadClassName, options, node) {
#     if (!imageLoadClassName && options && options.loadMode === 'onload') {
#       imageLoadClassName = 'onload-loadable';
#     }
#     imageLoadClassName = imageLoadClassName || defaults.imageLoadClassName;
#
#     options = mergeOptions(defaults.options, options);
#
#     var lazyImages = node
#       ? [].concat(node.classList.contains(imageLoadClassName) ? [node] : [])
#       : [].slice.call(document.querySelectorAll('.' + imageLoadClassName));
#
#     function loadImages(img) {
#       function setSource(attr, srcKey, srcFallbackKey) {
#         if (img.hasAttribute(srcKey)) {
#           var dataSrc = img.getAttribute(srcKey);
#           if (srcFallbackKey && img.hasAttribute(srcFallbackKey)) {
#             var dataSrcFallback = img.getAttribute(srcFallbackKey);
#             img.onload = function () {
#               img.removeAttribute(srcFallbackKey);
#             };
#             img.onerror = function () {
#               this.src = dataSrcFallback;
#               this.srcset = dataSrcFallback;
#               img.removeAttribute(srcFallbackKey);
#               img.onerror = null;
#             };
#           }
#           img.setAttribute(attr, dataSrc);
#           img.removeAttribute(srcKey);
#         }
#       }
#
#       setSource('src', dataSrcKey, dataSrcFallbackKey);
#       setSource('srcset', dataSrcSetKey);
#
#       img.classList.remove(imageLoadClassName);
#
#       if (img.classList.length < 1) {
#         img.removeAttribute('class');
#       }
#     }
#
#     function loadAllImages() {
#       lazyImages.forEach(function (image) {
#         loadImages(image);
#       });
#     }
#
#     if (supportIntersectionObserver && options.loadMode === 'lazy') {
#       var lazyImageObserver = new IntersectionObserver((function (entries) {
#         entries.forEach(function (entry) {
#           if (entry.isIntersecting) {
#             var lazyImage = entry.target;
#             loadImages(lazyImage);
#             lazyImageObserver.unobserve(lazyImage);
#           }
#         });
#       }), options);
#
#       lazyImages.forEach(function (lazyImage) {
#         lazyImageObserver.observe(lazyImage);
#       });
#
#       window.lazyImageObserver = lazyImageObserver;
#
#       // This condition enter on fallback or loadMode is onLoad
#     } else if ((!supportIntersectionObserver && options.loadMode === 'lazy') || options.loadMode === 'onload') {
#       if (document.readyState === 'complete') {
#         loadAllImages();
#       } else {
#         window.addEventListener('load', function () {
#           loadAllImages();
#         });
#       }
#     }
#   }
#
#   function initLazyLoading() {
#     imageLazyLoading();
#     imageLazyLoading('onload-loadable', { loadMode: 'onload' });
#   }
#
#   function initErrorLoading() {
#     var perfillNamespace = '_pfl';
#     var images = [].slice.call(document.querySelectorAll('img'));
#
#     var errorHandler = function (e) {
#       (window[perfillNamespace] = window[perfillNamespace] || []).push(['img', e.target.src]);
#     };
#
#     images.forEach(function (image) {
#       image.addEventListener('error', errorHandler);
#     });
#   }
#
#   window.imageLazyLoading = imageLazyLoading;
#   initLazyLoading();
#   initErrorLoading();
# }());
# }}]);
#   var scripts = [{s:function(){
#           var cookieButton = document.getElementById("newCookieDisclaimerButton");
#           if (!cookieButton) {
#             return;
#           }
#           var isMelidataAvailable = typeof melidata !== 'undefined';
#           cookieButton.addEventListener("click", function() {
#             var expiration_date = 365;
#             var now = new Date();
#             now.setDate(now.getDate() + expiration_date);
#             document.cookie = '_tc_cbanner_mco=1; expires=' + now.toUTCString() + '; path=/; domain=tucarro.com.co; SameSite=None; Secure';
#             var cookieBanner = document.getElementById("newCookieDisclaimerBanner");
#             if (cookieBanner) {
#               cookieBanner.parentNode.removeChild(cookieBanner);
#             }
#             isMelidataAvailable && melidata('cleanAndSend', 'event', { path: '/navigation/cookies_consent/ack' });
#             if (window.onCookieConsentBannerClosed) {
#               window.onCookieConsentBannerClosed();
#             }
#           });
#           isMelidataAvailable && melidata('cleanAndSend', 'event', {
#             path: '/navigation/cookies_consent/show',
#             data: {
#               consent_type: 'disclaimer'
#             }
#           });
#           var oldCookieBanner = document.getElementById("cookieDisclaimerBanner");
#           if (oldCookieBanner) {
#             oldCookieBanner.parentNode.removeChild(oldCookieBanner);
#           }
#         }},{s:function(){
#       !function(n,e){n.mitt=e()}(this,function(){function n(n){return n=n||Object.create(null),{on:function(e,t){(n[e]||(n[e]=[])).push(t)},off:function(e,t){n[e]&&n[e].splice(n[e].indexOf(t)>>>0,1)},emit:function(e,t){(n[e]||[]).map(function(n){n(t)}),(n["*"]||[]).map(function(n){n(e,t)})}}}return n});
#       window.freya = mitt();
#     }},{s:"https://http2.mlstatic.com/frontend-assets/vis-web-navigation/widgets/5.19.4/searchbox.js",c:function(){
#       if (window.Searchbox) {
#         new window.Searchbox('.nav-search-input', {
#           platformId: 'TC',
#           siteId: 'MCO',
#           siteDomain: 'tucarro.com.co',
#           limit: 6,
#           searchEndpoint: 'http://listado.tucarro.com.co/$query',
#           categoryEndpoint: 'null',
#           categoryCheckbox: document.getElementById('categorySearch'),
#           loggedIn: false,
#
#           bus: window.freya,
#           deviceType: 'desktop'
#         });
#       }
#     }},{s:function(){"use strict";!function(e,t){var n=t.getElementById("nav-footer-access-switch");function c(){var n=setInterval((function(){try{var c=Math.max(t.body.scrollHeight,t.body.offsetHeight,t.documentElement.clientHeight,t.documentElement.scrollHeight,t.documentElement.offsetHeight),o=e.pageYOffset||t.documentElement.scrollTop||t.body.scrollTop||0;e.innerHeight+o>=c?clearInterval(n):e.scrollBy(0,20)}catch(e){clearInterval(n)}}),15)}e.addEventListener&&n&&n.addEventListener("change",(function(){this.checked||setTimeout(c,200)}))}(window,document);
# }},{s:function(){"use strict";(function(a){var b=a.location.hostname.substr(a.location.hostname.indexOf("."),a.location.hostname.length);if(-1!==b.indexOf("mercadolibre")||-1!==b.indexOf("mercadolivre")||-1!==b.indexOf("mercadopago")){var c="https://matt"+b,d=a.location.href;if(c=c.concat("?go=").concat(encodeURIComponent(d)),navigator&&navigator.sendBeacon)status=navigator.sendBeacon(c);else{var e=new XMLHttpRequest;e.open("GET",c),e.send()}}})(window);}},{s:"https://http2.mlstatic.com/frontend-assets/vpp-frontend/polyfill.6f4bf9db.js"},{s:"https://http2.mlstatic.com/frontend-assets/vpp-frontend/vip.motors.desktop.431aa1d0.js"},{s:"https://http2.mlstatic.com/frontend-assets/frontend-viewability/viewability-script.0.0.4.js"},{s:function(){
#         var recaptchaScript = document.createElement('script');
#         recaptchaScript.src = 'https://www.google.com/recaptcha/enterprise.js?hl=es-419&render=6LfzJ8weAAAAANqQxOkJXmfFOmFv6H_qF34zV-EM';
#         document.head.appendChild(recaptchaScript);
#       }},{s:function(){
#     (function(h,o,t,j,a,r){
#       h.hj= h.hj || function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#       h._hjSettings={hjid:893036,hjdebug:false,hjsv:5};
#       a=o.getElementsByTagName('head')[0];
#       r=o.createElement('script');r.async=1;
#       r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
#       a.appendChild(r);
#     })(window,document,'//static.hotjar.com/c/hotjar-','.js?sv=');
#     hj('tagRecording', ["vis_vpp_mco_motors","vis_vpp_tc_mco_motors","user_type: normal"]);
#     hj('trigger', 'vis_vpp_mco_motors');
# 	hj('trigger', 'vis_vpp_tc_mco_motors');
# 	hj('trigger', 'vis_vpp_tc_mco_real_estate_reputation');
#     }},{s:function(){
# (function(w,d,s,l,i){
#   w[l]=w[l]||[];w[l].push({"pageId":"VIP","itemId":"MCO1268666883","sellerId":99473358,"categoryId":"MCO1744","rootCategoryId":"MCO1743","pathToRoot":"MCO1743,MCO1744","listingType":"gold","condition":"used","status":"active","siteId":"MCO","tagManagerId":"GTM-HD6Q","banks":"Banco De Bogota S.A.","data_audience_3p_denied":false});w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});
#   var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;
#   j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);d.addEventListener("cookiesConsentChange",function(e){try{for(var n={event:"cookieConsentEvent"},t=Object.keys(e.detail),o=0;o<t.length;o++)n["user_consent_cookies_"+t[o]]=e.detail[t[o]];w[l].push(n)}catch(e){}});
# })(window,document,'script','dataLayer','GTM-HD6Q');}},{s:"https://http2.mlstatic.com/frontend-assets/vpp-frontend/framework.4df77fba.js"},{s:"https://http2.mlstatic.com/frontend-assets/vpp-frontend/lib-97d8ebaa.2ba8227e.js"},{s:"https://http2.mlstatic.com/frontend-assets/vpp-frontend/commons.e10bac6e.js"},{s:"https://http2.mlstatic.com/frontend-assets/vpp-frontend/8834.644cfc78.js"},{s:"https://http2.mlstatic.com/frontend-assets/vpp-frontend/1972.62aac4c8.js"},{s:"https://http2.mlstatic.com/frontend-assets/vpp-frontend/6345.207ec450.js"},{s:"https://http2.mlstatic.com/frontend-assets/vpp-frontend/2649.6a574b66.js"},{s:"https://http2.mlstatic.com/frontend-assets/vpp-frontend/2510.020670bd.js"},{s:"https://http2.mlstatic.com/frontend-assets/vpp-frontend/395.67c0a563.js"},{s:"https://http2.mlstatic.com/frontend-assets/vpp-frontend/453.bb1e9aa8.js"},{s:"https://http2.mlstatic.com/frontend-assets/vpp-frontend/3818.92d90496.js"},{s:"https://http2.mlstatic.com/frontend-assets/vpp-frontend/3715.78310b18.js"},{s:"https://http2.mlstatic.com/frontend-assets/vpp-frontend/1611.4e834950.js"},{s:"https://http2.mlstatic.com/frontend-assets/vpp-frontend/9200.4eef5f5e.js"},{s:"https://http2.mlstatic.com/frontend-assets/vpp-frontend/5991.60a107e8.js"},{s:"https://http2.mlstatic.com/frontend-assets/vpp-frontend/2826.655dc1aa.js"},{s:"https://http2.mlstatic.com/frontend-assets/vpp-frontend/4282.597d9278.js"},{s:"https://http2.mlstatic.com/frontend-assets/vpp-frontend/4297.8dfede58.js"},{s:"https://http2.mlstatic.com/frontend-assets/vpp-frontend/7572.8c2097f2.js"},{s:"https://http2.mlstatic.com/frontend-assets/vpp-frontend/8121.55b40718.js"},{s:"https://http2.mlstatic.com/frontend-assets/vpp-frontend/action.b30b1e61.js"}];
#   if (doc.readyState === 'complete') {
#     loadScripts(scripts);
#   } else {
#     win.addEventListener('load', function(){ loadScripts(scripts); });
#   }
# })(window, document);
#   </script>
#  </body>
# </html>

# %%
short_description = soup.find('div', class_=lambda x: x and 'short-description' in x)

# %%
int(short_description.find('meta').get('content'))
# Out:
# 85900000

# %%
calcular_fecha_publicacion(' hace 20 días')
# Out:
# Timestamp('2023-03-08 00:00:00')

# %%
soup.find('div', class_=lambda x: x and 'seller-profile' in x)
# Out:
# <div class="ui-pdp-container__row ui-pdp-container__row--seller-profile" id="seller_profile"><div class="ui-vip-seller-profile ui-box-component" id="seller_profile"><h2 class="ui-pdp-color--BLACK ui-pdp-size--MEDIUM ui-pdp-family--REGULAR ui-vip-seller-profile__header mb-24">Información de la tienda</h2><div class="ui-vip-profile-info"><div class="ui-vip-profile-info__logo-container ui-vip-profile-info__logo-container-square"><img alt="Continautos" aria-hidden="true" class="ui-pdp-image ui-vip-profile-info__logo-image ui-vip-profile-info__logo-square lazy-loadable" data-src="https://resources.mlstatic.com/classifieds_accounts/MCO_car_dealer/99473358_vip.jpg" decoding="async" src="..."/></div><div class="ui-vip-profile-info__info-container"><div class="ui-vip-profile-info__info-link"><h3 class="ui-pdp-color--BLACK ui-pdp-size--LARGE ui-pdp-family--REGULAR">Continautos</h3><svg class="ui-pdp-icon ui-vip-profile-info__icon-normal" height="14" viewbox="0 0 14 14" width="14" xmlns="http://www.w3.org/2000/svg"><use href="#verified_small"></use></svg></div></div></div><ul class="ui-vip-seller-profile__list-extra-info"><div class="ui-seller-info__status-info"><figure aria-hidden="true" class="ui-seller-info__status-info__icon ui-pdp-color--BLACK ui-seller-info__status-row"><svg class="ui-pdp-icon ui-pdp-icon--pin ui-pdp-color--BLACK" height="16" viewbox="0 0 12 16" width="12" xmlns="http://www.w3.org/2000/svg"><use href="#location"></use></svg></figure><div><h3 class="ui-seller-info__status-info__title ui-vip-seller-profile__title">Ubicación del vehículo</h3><p class="ui-seller-info__status-info__subtitle">Montevideo - Fontibón - Bogotá D.C.</p></div></div><div class="ui-seller-info__status-info"><div><h3 class="ui-seller-info__status-info__title ui-vip-seller-profile__title"></h3><div class="ui-seller-info__status-info__container-phones"><div class="ui-seller-info__status-info-phones"><a class="ui-pdp-media__action" target="_self">Ver teléfono</a></div></div></div><div class="ui-pdp-recaptcha-v3"></div></div></ul><span class="ui-vip-seller-profile__property-link"><span class="ui-pdp-color--GRAY ui-pdp-size--XSMALL ui-pdp-family--REGULAR">Ir a la tienda oficial de </span><a class="ui-pdp-media__action" href="https://tienda.mercadolibre.com.co/continautos" target="_self">Continautos</a></span></div></div>

# %%
soup.find_all('svg', class_=lambda x: x and 'seller-profile' in x)
# Out:
# [<svg class="nav-header-menu-mobile-guest-icon" height="35" width="28" xmlns="http://www.w3.org/2000/svg"><path d="M27.343 33.706l-1.356.64A13.25 13.25 0 0 0 14 26.75c-5.17 0-9.8 2.988-11.978 7.578l-1.356-.643A14.75 14.75 0 0 1 14 25.25a14.75 14.75 0 0 1 13.343 8.456zM14 21.75C8.063 21.75 3.25 16.937 3.25 11S8.063.25 14 .25 24.75 5.063 24.75 11 19.937 21.75 14 21.75zm0-1.5a9.25 9.25 0 1 0 0-18.5 9.25 9.25 0 0 0 0 18.5zm0-2.5v-1.5a5.25 5.25 0 1 0 0-10.5v-1.5a6.75 6.75 0 0 1 0 13.5z" fill="#BBB" fill-rule="nonzero"></path></svg>,
#  <svg class="ui-vpp-svg-sprites" data-reactroot="" style="display:none" xmlns="http://www.w3.org/2000/svg"><defs><symbol id="loyalty_points"><path d="M7.598 8.746v1.252h.6c1.657 0 3 1.343 3.001 3v.6H2.798v-.602a2.998 2.998 0 0 1 2.998-2.997h.604l-.001-1.253a3.435 3.435 0 0 1-1.578-.724l-1.586-.446-.106-.041-.739-.37A3.6 3.6 0 0 1 .402 3.947V1.599h2.486l-.2-1.2h8.618l-.2 1.2h2.489v2.346a3.6 3.6 0 0 1-1.988 3.22l-.739.37-.106.041-1.592.448a3.43 3.43 0 0 1-1.572.722zm2.65-2.272l.134-.037.688-.345a2.4 2.4 0 0 0 1.326-2.147V2.799h-1.49l-.52 3.13c-.032.187-.078.37-.138.545zm-6.505-.001a3.453 3.453 0 0 1-.139-.552L3.087 2.8H1.602v1.148a2.4 2.4 0 0 0 1.325 2.145l.687.345.129.036zm.361-4.874l.684 4.126a2.24 2.24 0 0 0 2.21 1.874c1.092 0 2.024-.79 2.204-1.868L9.89 1.6H4.104zm4.094 9.6H5.795c-.784 0-1.45.5-1.697 1.199h5.799c-.248-.699-.915-1.2-1.7-1.2z" fill-rule="nonzero"></path></symbol></defs><defs><symbol id="protected_buy"><path d="M.399 3.89v-.6h.6c1.87 0 3.76-.783 5.68-2.374l.383-.317.383.317c1.92 1.59 3.81 2.374 5.68 2.374h.6v.6c0 5.633-2.165 9.242-6.473 10.679l-.19.063-.19-.063C2.564 13.132.4 9.523.4 3.89zm6.663-1.743c-1.8 1.4-3.62 2.179-5.455 2.32.135 4.725 1.947 7.648 5.455 8.898 3.508-1.25 5.32-4.173 5.455-8.898-1.835-.141-3.656-.92-5.455-2.32zm-.905 6.477l3.191-3.582.896.798-4.02 4.513-2.472-2.377.831-.865 1.574 1.513z" fill-rule="nonzero"></path></symbol></defs><defs><symbol id="returns"><path d="M2.474 7.2h7.225a2.7 2.7 0 1 0 0-5.4H7V.6h2.7a3.9 3.9 0 1 1 0 7.8H2.473l2.45 2.389-.839.859L.14 7.8l3.945-3.848.838.859L2.473 7.2z"></path></symbol></defs><defs><symbol id="warranty"><path d="M5.305 10.354l-1.686 3.34-1.24-2.458H0l1.64-3.202a5.2 5.2 0 1 1 8.588.194l1.54 3.008H9.39l-1.241 2.458-1.673-3.315a5.266 5.266 0 0 1-1.171-.025zm-1.001-.237a5.201 5.201 0 0 1-1.975-1.234l-.693 1.353h1.357l.626 1.239.685-1.358zm3.192.064l.653 1.294.625-1.239h1.358l-.617-1.204a5.193 5.193 0 0 1-2.019 1.15zM6 9.2a4 4 0 1 0 0-8 4 4 0 0 0 0 8z" fill-rule="nonzero"></path></symbol></defs><defs><symbol id="sharegallery"><g fill="none" fill-rule="evenodd"><circle cx="20" cy="20" fill="#F5F5F5" r="20"></circle><g transform="translate(9 10)"><path d="M7.565 11.848a3.002 3.002 0 1 1 0-3.707l4.337-2.173a3.006 3.006 0 0 1 2.9-3.783 3.002 3.002 0 1 1-2.362 4.856L8.102 9.214a3.006 3.006 0 0 1 0 1.562l4.337 2.17a3.002 3.002 0 1 1-.537 1.073l-4.337-2.17zm-2.363-.05a1.802 1.802 0 1 0 0-3.605 1.802 1.802 0 0 0 0 3.604zm9.6 4.802a1.802 1.802 0 1 0 0-3.605 1.802 1.802 0 0 0 0 3.605zm0-9.61a1.802 1.802 0 1 0 0-3.605 1.802 1.802 0 0 0 0 3.605z" fill="#333" fill-rule="nonzero"></path></g></g></symbol></defs><defs><symbol id="loyalty_trophy_rounded"><path d="M24 0c13.255 0 24 10.745 24 24S37.255 48 24 48 0 37.255 0 24 10.745 0 24 0zm6.885 14.25H17.114l.169 1.01-3.033-.05v4.011a5.75 5.75 0 0 0 3.057 5.08l5.942 3.15v1.799H21A3.75 3.75 0 0 0 17.25 33v.75h13.5V33A3.75 3.75 0 0 0 27 29.25h-2.25v-1.799l5.943-3.15a5.75 5.75 0 0 0 3.058-5.08v-4.01l-3.034.05.169-1.011zm-3.886 16.5c.98 0 1.814.626 2.122 1.5H18.877A2.25 2.25 0 0 1 21 30.75zm2.115-15l-.908 5.459a5.49 5.49 0 0 1-2.371 3.667l-1.142.76c-.42.28-.967.28-1.387 0l-1.14-.76a5.492 5.492 0 0 1-2.371-3.666l-.91-5.46h10.23zm-13.364.986l1.783.029.782 4.691c.12.718.35 1.405.675 2.04l-.98-.52a4.25 4.25 0 0 1-2.26-3.755v-2.485zm16.5 0v2.485a4.25 4.25 0 0 1-2.26 3.755l-.979.519a6.988 6.988 0 0 0 .674-2.04l.781-4.69 1.784-.03z" fill-rule="evenodd"></path></symbol></defs><defs><symbol id="rounded_truck_medium_alt"><path d="M15 29.75C6.867 29.75 0.25 23.133 0.25 15C0.25 6.867 6.867 0.25 15 0.25c8.133 0 14.75 6.617 14.75 14.75 C29.75 23.133 23.133 29.75 15 29.75z M15 1.25C7.418 1.25 1.25 7.418 1.25 15c0 7.582 6.168 13.75 13.75 13.75 c7.582 0 13.75-6.168 13.75-13.75C28.75 7.418 22.582 1.25 15 1.25z" stroke="#00a650" stroke-width="0.5"></path><path d="M14.29 19.292c-0.297 0.985-1.212 1.702-2.293 1.702c-1.083 0-1.997-0.719-2.294-1.703L9.001 19.29 c-0.994 0-1.8-0.806-1.8-1.8v-6.695c0-0.994 0.806-1.8 1.8-1.8h6.664c0.994 0 1.8 0.806 1.8 1. ...
#  <svg height="8" width="6" xmlns="http://www.w3.org/2000/svg"><path d="M1 0l4 4-4 4" fill="none" stroke="#666"></path></svg>,
#  <svg height="8" width="6" xmlns="http://www.w3.org/2000/svg"><path d="M1 0l4 4-4 4" fill="none" stroke="#666"></path></svg>,
#  <svg height="8" width="6" xmlns="http://www.w3.org/2000/svg"><path d="M1 0l4 4-4 4" fill="none" stroke="#666"></path></svg>,
#  <svg class="ui-pdp-icon ui-pdp-seller-validated__icon" height="14" viewbox="0 0 14 14" width="14" xmlns="http://www.w3.org/2000/svg"><use href="#verified_small"></use></svg>,
#  <svg class="ui-pdp-icon ui-pdp-icon--whatsapp ui-pdp-color--BLUE" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg"><use href="#whatsapp"></use></svg>,
#  <svg class="ui-pdp-icon ui-pdp-icon--chevron ui-pdp-icon--chevron-right" viewbox="0 0 9 14" xmlns="http://www.w3.org/2000/svg"><use href="#chevron"></use></svg>,
#  <svg class="ui-pdp-icon ui-vip-profile-info__icon-normal" height="14" viewbox="0 0 14 14" width="14" xmlns="http://www.w3.org/2000/svg"><use href="#verified_small"></use></svg>,
#  <svg class="ui-pdp-icon ui-pdp-icon--pin ui-pdp-color--BLACK" height="16" viewbox="0 0 12 16" width="12" xmlns="http://www.w3.org/2000/svg"><use href="#location"></use></svg>]

# %%
##############

# %%
for i in soup.find('div', class_=lambda x: x and 'specs__table' in x ).find_all('span'):
    print(i.text)
# Out:
# Chevrolet
# Tracker
# 2019
# 1.8 Ltz
# Negro
# Gasolina
# 5
# Automática
# 1.8
# Camioneta
# 39929 km

# %%
for i in soup.find('div', class_=lambda x: x and 'specs__table' in x ).find_all('th'):
    print(i.text)
# Out:
# Marca
# Modelo
# Año
# Versión
# Color
# Tipo de combustible
# Puertas
# Transmisión
# Motor
# Tipo de carrocería
# Kilómetros

# %%
soup.find('script', {'type': 'application/ld+json'})
# Out:
# <script type="application/ld+json">{"name":"Chevrolet Tracker Ltz Mod 2019 4x4 Aut","image":"https:\u002F\u002Fhttp2.mlstatic.com\u002FD_NQ_NP_973198-MCO54244390411_032023-O.webp","offers":{"price":85900000,"availability":"http:\u002F\u002Fschema.org\u002FInStock","url":"https:\u002F\u002Fcarro.mercadolibre.com.co\u002FMCO-1268666883-chevrolet-tracker-ltz-mod-2019-4x4-aut-_JM","@type":"Offer","priceCurrency":"COP","priceValidUntil":"2023-03-31"},"brand":"Chevrolet","sku":"MCO1268666883","color":"Negro","@context":"http:\u002F\u002Fschema.org","@type":"Vehicle","itemCondition":"https:\u002F\u002Fschema.org\u002FUsedCondition","productID":"MCO1268666883","bodyType":"Camioneta","fuelType":"Gasolina","numberOfDoors":"5","vehicleEngine":"1.8","vehicleTransmission":"Automática"}</script>

# %%
####

# %%
soup.find('div', {'class': 'andes-tab-content', 'id': 'tab-content-id-confort-y-conveniencia'})
# Out:
# <div class="andes-tab-content" id="tab-content-id-confort-y-conveniencia" role="tabpanel" tabindex="0"><div class="ui-pdp-specs__tab-spec"><p class="ui-pdp-family--REGULAR ui-pdp-specs__specs-list"><span class="ui-pdp-color--BLACK ui-pdp-size--XSMALL ui-pdp-family--REGULAR">Aire acondicionado</span></p></div></div>
